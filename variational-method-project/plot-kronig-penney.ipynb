# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("b0.csv") 
df2 = pd.read_csv("b25.csv")
df3 = pd.read_csv("b50.csv")
df4 = pd.read_csv("b75.csv")
df5 = pd.read_csv("teste.csv") # 1*b

# df.columns 
# df['k']
# df.head()
# df['  k'] = np.real(df['  k'])#[::]
# df.head()

# %%
df.columns
# Out:
# Index(['# k', 'n=0', 'n=1', 'n=2', 'n=3'], dtype='object')

# %%
igname = 'bands.png'
plt.subplot(1, 5, 1)
plt.title("a=0", fontsize=25)
plt.ylim(0,140)
plt.yticks(fontsize=20)
plt.xticks([-3.4,0,3.4],[r'-$\pi/a$',0,r'$\pi/a$'],fontsize=25)
plt.plot(df['# k'],df['n=0'],label='n=0',linewidth=3)
plt.plot(df['# k'],df['n=1'],label='n=1',linewidth=3)
plt.plot(df['# k'],df['n=2'],label='n=2',linewidth=3)
plt.plot(df['# k'],df['n=3'],label='n=3',linewidth=3)
plt.legend()

plt.subplot(1, 5, 2)
plt.title("a=0.25b", fontsize=25)
plt.ylim(0,140)
plt.yticks(fontsize=20)
plt.xticks([-3.4,0,3.4],[r'-$\pi/a$',0,r'$\pi/a$'],fontsize=25)
plt.plot(df2['# k'],df2['n=0'],label='n=0',linewidth=3)
plt.plot(df2['# k'],df2['n=1'],label='n=1',linewidth=3)
plt.plot(df2['# k'],df2['n=2'],label='n=2',linewidth=3)
plt.plot(df2['# k'],df2['n=3'],label='n=3',linewidth=3)
plt.legend()
# plt.xlabel('time (s)')
# plt.ylabel('Undamped')

plt.subplot(1, 5, 3)
plt.title("a=0.50b", fontsize=25)
plt.ylim(0,140)
plt.yticks(fontsize=20)
plt.xticks([-3.4,0,3.4],[r'-$\pi/a$',0,r'$\pi/a$'],fontsize=25)
plt.plot(df3['# k'],df3['n=0'],label='n=0',linewidth=3)
plt.plot(df3['# k'],df3['n=1'],label='n=1',linewidth=3)
plt.plot(df3['# k'],df3['n=2'],label='n=2',linewidth=3)
plt.plot(df3['# k'],df3['n=3'],label='n=3',linewidth=3)
plt.legend()

plt.subplot(1, 5, 4)
plt.title("a=0.75b", fontsize=25)
plt.ylim(0,140)
plt.yticks(fontsize=20)
plt.xticks([-3.4,0,3.4],[r'-$\pi/a$',0,r'$\pi/a$'],fontsize=25)
plt.plot(df4['# k'],df4['n=0'],label='n=0',linewidth=3)
plt.plot(df4['# k'],df4['n=1'],label='n=1',linewidth=3)
plt.plot(df4['# k'],df4['n=2'],label='n=2',linewidth=3)
plt.plot(df4['# k'],df4['n=3'],label='n=3',linewidth=3)
plt.legend()

plt.subplot(1, 5, 5)
plt.title("a=b", fontsize=25)
plt.ylim(0,140)
plt.yticks(fontsize=20)
plt.xticks([-3.4,0,3.4],[r'-$\pi/a$',0,r'$\pi/a$'],fontsize=25)
plt.plot(df5['# k'],df5['n=0'],label='n=0',linewidth=3)
plt.plot(df5['# k'],df5['n=1'],label='n=1',linewidth=3)
plt.plot(df5['# k'],df5['n=2'],label='n=2',linewidth=3)
plt.plot(df5['# k'],df5['n=3'],label='n=3',linewidth=3)
plt.legend()

plt.tight_layout()
plt.savefig(f'{figname}', dpi=300, bbox_inches='tight')
plt.rcParams['figure.figsize'] = [20, 8]
