# %%
import numpy as np
import matplotlib.pyplot as plt 
from funcoes import basis_sin,V,second_derivative
from scipy import integrate
import numpy.linalg as la
from scipy.linalg import eigh_tridiagonal
# %matplotlib inline

# %%
# Parâmetros do problema
a = 0 # início do intervalo
b = 1 # final do intervalo
interval_number = 2000 # numero de divisoes do espaço

# step (h) do intervalo de x 

h = (b-a)/interval_number

# %%
# Arrays declarados
x = np.linspace(a, b, interval_number) # array com o intervalo
n = np.linspace(1, 10, 10) # numero de bases
# n = np.linspace(1, 2, 2) # numero de bases

# %%
psi = basis_sin(x, n, b)
V_x = V(x)
plt.plot(x,V_x)

# %%
# até aqui funciona para calcular os arrays
psi_der_arr = [[] for _ in range(len(n))]
for i in range(len(n)):
    psi_der = second_derivative(psi[i], h)
    psi_der_arr[i] = list(psi_der)

# %%
for i in range(len(n)):
    plt.plot(x, psi[i])

# %%
for i in range(len(n)):
    plt.plot(x, psi_der_arr[i])

# %%
psi_der_arr = np.asarray(psi_der_arr)

# %%
shape = ( len(n), len(n), interval_number)
# shape = (2,2)

integrand_matrix = np.zeros(shape)
#A, B = rand.random(size=shape)
# print(integrand_matrix)
# print(integrand_matrix[0])

# print(integrand_matrix[0][1])

# %%
# Integando energia cinética
# i,j --> n,m (referente a qual base psi_n usada)
# k --> posicao de h
# integrand_arr= [[] for _ in range(len(n) * len(n))]
for i in range(len(n)):
    for j in range(len(n)):
        integrand_list = []
        for k in range(interval_number):
            integrand = (-0.5) * psi_der_arr[i][k] * psi[j][k]
            integrand_list.append(integrand)
        integrand_matrix[i][j] = list(integrand_list)
    # integrand_arr[i] = list(integrand_list)
#print(integrand_list)

# %%
len(integrand_matrix[0][1])
# Out:
# 2000

# %%
plt.plot(x, integrand_matrix[0][1])
plt.plot(x, integrand_matrix[0][2])
plt.plot(x, integrand_matrix[0][3])
plt.plot(x, integrand_matrix[0][4])

# %%
integrate.simpson(integrand_matrix[0][9], x)
# Out:
# 6.968170995541587e-15

# %%
shape_Tmn = (len(n), len(n))
print(len(n))
T_mn = np.zeros(shape_Tmn)
# Out:
# 100

# %%
T_mn[0][0]
# Out:
# 0.0

# %%
for i in range(len(n)):
    for j in range(len(n)):
        integral = integrate.simpson(integrand_matrix[i][j], x)
        T_mn[i][j] = integral

# %%
T_mn[0][1]
# Out:
# 1.5212825627185777e-15

# %%
e_vals, e_vecs = la.eig(T_mn)

# %%
# integrando do potencial Vmn
shape = ( len(n), len(n), interval_number)
# shape = (2,2)

integrand_potential_matrix = np.zeros(shape)
for i in range(len(n)):
    for j in range(len(n)):
        integrand_list = []
        for k in range(interval_number):
            integrand = psi[i][k] * V_x[k] * psi[j][k]
            integrand_list.append(integrand)
        integrand_potential_matrix[i][j] = list(integrand_list)

# %%
plt.plot(x,integrand_potential_matrix[0][0])

# %%
shape_Vmn = (len(n), len(n))
print(len(n))
V_mn = np.zeros(shape_Vmn)
# Out:
# 100

# %%
for i in range(len(n)):
    for j in range(len(n)):
        integral = integrate.simpson(integrand_potential_matrix[i][j], x)
        V_mn[i][j] = integral

# %%
shape_Hmn = (len(n), len(n))
print(len(n))
H_mn = np.zeros(shape_Hmn)
# Out:
# 100

# %%
for i in range(len(n)):
    for j in range(len(n)):
        H_mn[i][j] = T_mn[i][j] + V_mn[i][j]

# %%
e_vals, e_vecs = la.eig(H_mn)

# %%
e_vals.T
# Out:
# array([267958.45331775, 239420.44048224, 250305.26575248, 229992.76970873,
#        268774.84998163, 220935.08433192, 212078.64812377, 203420.76446866,
#        250978.21019446, 194961.15263456, 186699.93720487, 240058.4193047 ,
#        230686.29831491, 178637.23624775, 221708.17618325, 212928.88337247,
#        170773.18347764, 204344.39668535, 163107.93030382, 195954.3350641 ,
#        187758.82810794, 155641.64986318, 148374.54181833, 141306.83812148,
#        179757.99388819, 134438.81001368, 171951.96653108, 164340.89778129,
#        127770.77664587, 156924.96094588, 121303.11585012, 115036.27778209,
#        149704.35556604, 142679.31303031, 108970.80243129,    707.44487046,
#        135850.10338421, 103107.34239714, 129217.04370427,   3537.09921683,
#          6366.5032715 ,  97446.69292127, 122780.50853834,  91989.8320502 ,
#        116540.94309673,  86737.97512087, 110498.88013712, 104654.96186242,
#         81692.64970289,   9195.65700126,   2122.30332803,  12024.56037287,
#         99009.96870318,  76855.79982779,  14853.21335307,   4951.8325327 ,
#         93564.85767837,  72229.93140957,  17681.61590861,   7781.11142907,
#         88320.81425177,  10610.13998391,  20509.7680062 ,  67818.31140285,
#         83279.32340215,  23337.66961286,  63625.21881414,  13438.91816398,
#         78442.26814385,  26165.32070553,  59656.1663907 ,  16267.445936  ,
#         55917.69185421,  28992.72150514,  31819.87658337,  52415.27208045,
#         73812.06669865,  19095.72326673,  49145.72361957,  34646.84681551,
#         46081.22835563,  37474.21384914,  43159.13307221,  40305.87291626,
#         21923.75012287,  69391.86068212,  24751.52647181,  65185.75576441,
#         27579.05230086,  57438.14719426,  61199.05279655,  30406.32804269,
#         36060.24671063,  33233.36140439,  38887.81607015,  41721.204712  ,
#         44581.30868955,  50610.31460223,  53908.9029728 ,  47519.96152281])

# %%
e_vecs[0].T
# Out:
# array([ 5.14623432e-04, -6.80779863e-03,  2.42623210e-03, -1.25328180e-02,
#         6.23997298e-16, -1.83399676e-02,  2.41306476e-02,  2.98550937e-02,
#         7.21128924e-16, -3.55394959e-02,  4.11536688e-02,  3.64307760e-16,
#         1.71489028e-15, -4.67077862e-02,  1.55128451e-16, -7.10461359e-15,
#        -5.21805384e-02, -2.46221820e-15, -5.75755323e-02,  3.07840423e-15,
#        -1.84276641e-16,  6.28755287e-02, -6.80802836e-02,  7.31745605e-02,
#         4.34803209e-16,  7.81553226e-02, -1.13644724e-15,  4.44714040e-15,
#         8.30081033e-02,  5.56708120e-17, -8.77273821e-02, -9.22984519e-02,
#        -1.01511049e-14,  4.97451609e-15, -9.67130850e-02, -4.32736221e-01,
#         5.50637309e-15, -1.00955194e-01,  8.43782954e-15, -3.01707920e-01,
#        -2.57595504e-01, -1.05013009e-01, -1.91297094e-14,  1.08867399e-01,
#        -1.01971695e-14, -1.12501226e-01, -8.48936263e-15, -6.56185713e-15,
#         1.15889403e-01, -2.31798032e-01,  6.31169006e-15, -2.13705471e-01,
#         1.13518564e-14,  1.19005625e-01, -1.99791556e-01, -2.94381322e-15,
#        -4.88575924e-15, -1.21813189e-01,  1.88477700e-01, -6.14742299e-16,
#         2.39817823e-16, -8.87428930e-16, -1.78928749e-01,  1.24268835e-01,
#         1.30859767e-14, -1.70652261e-01,  1.26313872e-01,  2.05468093e-15,
#        -6.59949638e-15, -1.63334785e-01, -1.27878433e-01,  4.49997957e-15,
#        -1.28890135e-01,  1.56765116e-01, -1.50794796e-01, -1.29345976e-01,
#        -1.18428840e-14,  1.23820264e-15,  1.29509319e-01,  1.45318906e-01,
#         1.30156505e-01, -1.40284582e-01, -1.32210494e-01, -1.35778874e-01,
#         1.59862429e-15, -6.23997059e-15,  1.85417255e-15, -9.46937671e-15,
#        -5.64298753e-15, -1.17430123e-14,  1.44329672e-14, -1.08712892e-14,
#        -1.32427369e-14, -3.74047347e-15, -7.47673812e-15,  1.08357530e-14,
#         5.37861816e-15, -1.07159499e-15, -1.55859186e-15,  5.54504063e-16])

# %%
for i in range(1):
    # plt.plot(e_vecs[i].T)
    plt.plot(e_vecs.T[i], label="n = " + str(i))
plt.legend()

# %%
plt.plot(e_vecs.T[1], label="n = " + str(1))
plt.legend()

# %%
plt.plot(e_vecs.T[2], label="n = " + str(2))
plt.legend()

# %%
plt.bar(np.arange(0,10,1), e_vals[0:10])
# Out:
# <BarContainer object of 10 artists>
